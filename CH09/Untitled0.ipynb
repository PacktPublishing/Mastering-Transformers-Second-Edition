# %%
# !pip install transformers datasets accelerate nvidia-ml-py3

# %%
from pynvml import *


def print_gpu_utilization():
    nvmlInit()
    handle = nvmlDeviceGetHandleByIndex(0)
    info = nvmlDeviceGetMemoryInfo(handle)
    print(f"GPU memory occupied: {info.used//1024**2} MB.")


def print_summary(result):
    print(f"Time: {result.metrics['train_runtime']:.2f}")
    print(f"Samples/second: {result.metrics['train_samples_per_second']:.2f}")
    print_gpu_utilization()
#Let’s verify that we start with a free GPU memory:

print_gpu_utilization()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pynvml/nvml.py in _LoadNvmlLibrary()
#    1797                         # assume linux
# -> 1798                         nvmlLib = CDLL("libnvidia-ml.so.1")
#    1799                 except OSError as ose:
#
# /usr/lib/python3.10/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373         if handle is None:
# --> 374             self._handle = _dlopen(self._name, mode)
#     375         else:
#
# OSError: libnvidia-ml.so.1: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# NVMLError_LibraryNotFound                 Traceback (most recent call last)
# <ipython-input-5-5044179d0333> in <cell line: 17>()
#      15 #Let’s verify that we start with a free GPU memory:
#      16
# ---> 17 print_gpu_utilization()
#
# <ipython-input-5-5044179d0333> in print_gpu_utilization()
#       3
#       4 def print_gpu_utilization():
# ----> 5     nvmlInit()
#       6     handle = nvmlDeviceGetHandleByIndex(0)
#       7     info = nvmlDeviceGetMemoryInfo(handle)
#
# /usr/local/lib/python3.10/dist-packages/pynvml/nvml.py in nvmlInit()
#    1768
#    1769 def nvmlInit():
# -> 1770     nvmlInitWithFlags(0)
#    1771     return None
#    1772
#
# /usr/local/lib/python3.10/dist-packages/pynvml/nvml.py in nvmlInitWithFlags(flags)
#    1751 ## C function wrappers ##
#    1752 def nvmlInitWithFlags(flags):
# -> 1753     _LoadNvmlLibrary()
#    1754
#    1755     #
#
# /usr/local/lib/python3.10/dist-packages/pynvml/nvml.py in _LoadNvmlLibrary()
#    1798                         nvmlLib = CDLL("libnvidia-ml.so.1")
#    1799                 except OSError as ose:
# -> 1800                     _nvmlCheckReturn(NVML_ERROR_LIBRARY_NOT_FOUND)
#    1801                 if (nvmlLib == None):
#    1802                     _nvmlCheckReturn(NVML_ERROR_LIBRARY_NOT_FOUND)
#
# /usr/local/lib/python3.10/dist-packages/pynvml/nvml.py in _nvmlCheckReturn(ret)
#     831 def _nvmlCheckReturn(ret):
#     832     if (ret != NVML_SUCCESS):
# --> 833         raise NVMLError(ret)
#     834     return ret
#     835
#
# NVMLError_LibraryNotFound: NVML Shared Library Not Found

# %%
from transformers import AutoModelForSequenceClassification


model = AutoModelForSequenceClassification.from_pretrained("bert-large-uncased").to("cuda")
print_gpu_utilization()
GPU memory occupied: 2631 MB.
